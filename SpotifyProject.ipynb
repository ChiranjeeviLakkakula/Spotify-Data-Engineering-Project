# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="b83df96049fc4f8fb423ba264370b4a8", client_secret="f7d8e4d7f06049bfb71deef68fc2ce35")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlists = sp.user_playlists('spotify')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
playlist_URI = playlist_link.split('/')[-1].split('?')[0]

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
sp_date = sp.playlist_tracks(playlist_URI)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
sp_data = sp_date

# %%
sp_data['items'][1]['track']['album']['id']
# Out:
# '7aJuG4TFXa2hmE4z1yxc3n'

# %%
sp_data['items'][9]['track']['album']['name']
# Out:
# 'The Emptiness Machine'

# %%
sp_data['items'][1]['track']['album']['release_date']
# Out:
# '2024-05-17'

# %%
sp_data['items'][1]['track']['album']['total_tracks']
# Out:
# 10

# %%
sp_data['items'][1]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'

# %%
album_list = []
for row in sp_data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    album_elements = {'album_id':album_id,'album_name':album_name,'album_release_date':album_release_date,'total_tracks':total_tracks,'album_url':album_url}
    
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'album_release_date': '2024-08-16',
#   'total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'album_name': 'Timeless',
#   'album_release_date': '2024-09-27',
#   'total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2IRxVVqbSbqHJo8Zx50LYn'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'album_release_date': '2024-07-19',
#   'total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'total_tracks': 12,
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     datetime64[ns]
#  3   total_tracks        50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            44 non-null     object
#  1   album_name          44 non-null     object
#  2   album_release_date  44 non-null     datetime64[ns]
#  3   total_tracks        44 non-null     int64
#  4   album_url           44 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
sp_data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#   'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#   'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'name': 'Billie Eilish',
#   'type': 'artist',
#   'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}]

# %%
artist_list=[]
for row in sp_date['items']:
    for artist in row['track']['artists']:
        artist_disct = {'artist_id':artist['id'],'artist_name':artist['name'],'artist_url':artist['href']}
        artist_list.append(artist_disct)
        
        artist_df = pd.DataFrame.from_dict(artist_list)
        
        artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                  artist_id         artist_name  \
# 0   1HY2Jd0NmPuamShAr6KMms           Lady Gaga
# 1   0du5cEVh5yTK9QJze8zA0C          Bruno Mars
# 2   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish
# 3   1Xyo4u8uXC1ZmMpatF05PJ          The Weeknd
# 4   699OTQXzgjhIYAHMy9RyPD       Playboi Carti
# 5   1oSPZhvZMIrWW5I41kPkkY               Jimin
# 6   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter
# 8   7GlBOeep6PqTfFi59PTUUN       Chappell Roan
# 9   790FomKkXshlbRYZFtlgla             KAROL G
# 11  6XyY86QOPPrYVGvF9ch6wz         Linkin Park
# 12  22wbnEMDvgVIAGdFeek6ET        Benson Boone
# 14  3y2cIKLjiOlp1Np37WiUdH           Shaboozey
# 15  33qOK5uJ8AR2xuQQAhHump         Teddy Swims
# 17  2FXC3k01G6Gw61bmprjgqS              Hozier
# 18  77SW9BnxLY8rJ0RciFqkHh   The Neighbourhood
# 21  250b0Wlc5Vk0CoUsaCY84M              JENNIE
# 22  1pBLC0qVRTB5zVMuteQ9jJ      Lily-Rose Depp
# 23  1iCnM8foFssWlPRLfAbIwo          Gigi Perez
# 24  7Ln80lUS6He07XvHI8qqHH      Arctic Monkeys
# ...

# %%
sp_data['items'][1]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
song_list = []
for row in sp_data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)
    
    songs_df = pd.DataFrame(song_list)
    
    songs_df = songs_df.drop_duplicates(subset=['song_id'])

# %%
songs_df['song_added'] = pd.to_datetime(songs_df['song_added'])

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
! python --version
# Out:
# Python 3.11.5

# %%
test_list = [1,2,3,4]
test_list[1:]
# Out:
# [2, 3, 4]
